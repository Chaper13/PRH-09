# %%
# !git clone https://github.com/Chaper_13/rigidez_psv.git
# %cd rigidez_psv

# %%
# !pip install tqdm

# %%
# !python rigidez_psv.py

# %%
from google.colab import files
files.download("SAIDA_Rigidez_Global.txt")
